# %%
# importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# load data for analysis
student_df = pd.read_csv('student_data.csv')

# %%
student_df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
# show all columns
student_df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %% [markdown]
# **Dataset Description** <br>
# There are 395 entries and 33 columns in this data. Attributes for student_data.csv dataset are:
# - school - student's school ('GP' - Gabriel Pereira or 'MS' - Mousinho da Silveira)
# - sex - student's sex ('F' - female or 'M' - male)
# - age - student's age
# - address - student's home address type ('U' - urban or 'R' - rural)
# - famsize - family size ('LE3' - less or equal to 3 or 'GT3' - greater than 3)
# - Pstatus - parent's cohabitation status ('T' - living together or 'A' - apart)
# - Medu - mother's education
# - Fedu - father's education
# - Mjob - mother's job
# - Fjob - father's job
# - reason - reason to choose this school
# - guardian - student's guardian
# - traveltime - travel time from home to school
# - studytime - weekly study time
# - failures - number of past class failures
# - schoolsup - extra educational support
# - famsup - family educational support
# - paid - extra paid classes
# - activities - extra-curricular activities
# - nursery - attended nursery school
# - higher - wants to take higher education
# - internet - internet access at home
# - romantic - in a romantic relationship
# - famrel - quality of family relationships
# - freetime - free time after school
# - goout - going out with friends
# - Dalc - workday alcohol consumption
# - Walc - weekend alcohol consumption
# - health - current health status
# - absences - number of school absences
# - G1 - first period grade
# - G2 - second period grade
# - G3 - final grade

# %% [markdown]
# **Data Visualization & Data Preprocessing**

# %% [markdown]
# There are no missing values in this dataset.

# %%
student_df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
# get all object dtype columns
df_cat = student_df.select_dtypes(include='object')
cols_cat = df_cat.columns.to_list()

def count_plot(col):
    plt.figure(figsize=(3,3))
    sns.countplot(x=col,data=student_df,palette ='hls')
    plt.show()
    print(col)
    print(student_df[col].value_counts())

for i in cols_cat:
    count_plot(i)
# Out:
# school
# GP    349
# MS     46
# Name: school, dtype: int64
# sex
# F    208
# M    187
# Name: sex, dtype: int64
# address
# U    307
# R     88
# Name: address, dtype: int64
# famsize
# GT3    281
# LE3    114
# Name: famsize, dtype: int64
# Pstatus
# T    354
# A     41
# Name: Pstatus, dtype: int64
# Mjob
# other       141
# services    103
# at_home      59
# teacher      58
# health       34
# Name: Mjob, dtype: int64
# Fjob
# other       217
# services    111
# teacher      29
# at_home      20
# health       18
# Name: Fjob, dtype: int64
# reason
# course        145
# home          109
# reputation    105
# other          36
# Name: reason, dtype: int64
# guardian
# mother    273
# father     90
# other      32
# Name: guardian, dtype: int64
# schoolsup
# no     344
# yes     51
# Name: schoolsup, dtype: int64
# famsup
# yes    242
# no     153
# Name: famsup, dtype: int64
# paid
# no     214
# yes    181
# Name: paid, dtype: int64
# activities
# yes    201
# no     194
# ...

# %%
# get all numeric columns
df_num = student_df.select_dtypes(include='number')
cols_num = df_num.columns.to_list()

def hist_plot(col):
    plt.figure(figsize=(3,3))
    sns.kdeplot(x=col,data=student_df)
    plt.show()
    print(col)
    print(student_df[col].value_counts())

for i in cols_num:
    hist_plot(i)
# Out:
# age
# 16    104
# 17     98
# 18     82
# 15     82
# 19     24
# 20      3
# 22      1
# 21      1
# Name: age, dtype: int64
# Medu
# 4    131
# 2    103
# 3     99
# 1     59
# 0      3
# Name: Medu, dtype: int64
# Fedu
# 2    115
# 3    100
# 4     96
# 1     82
# 0      2
# Name: Fedu, dtype: int64
# traveltime
# 1    257
# 2    107
# 3     23
# 4      8
# Name: traveltime, dtype: int64
# studytime
# 2    198
# 1    105
# 3     65
# 4     27
# Name: studytime, dtype: int64
# failures
# 0    312
# 1     50
# 2     17
# 3     16
# Name: failures, dtype: int64
# famrel
# 4    195
# 5    106
# 3     68
# 2     18
# 1      8
# Name: famrel, dtype: int64
# freetime
# 3    157
# 4    115
# 2     64
# 5     40
# 1     19
# Name: freetime, dtype: int64
# goout
# 3    130
# 2    103
# 4     86
# 5     53
# 1     23
# Name: goout, dtype: int64
# Dalc
# 1    276
# 2     75
# 3     26
# 5      9
# 4      9
# Name: Dalc, dtype: int64
# Walc
# 1    151
# 2     85
# 3     80
# 4     51
# ...

# %% [markdown]
# **Handling columns with binary values** <br>
# Column 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic' have values of yes or no, I want to convert to numerical equiavelent.

# %%
def convert_binary(data):
    if data == "yes":
        return 1
    elif data == "no":
        return 0
    
student_df['schoolsup'] = student_df['schoolsup'].apply(convert_binary)
student_df['famsup'] = student_df['famsup'].apply(convert_binary)
student_df['paid'] = student_df['paid'].apply(convert_binary)
student_df['activities'] = student_df['activities'].apply(convert_binary)
student_df['nursery'] = student_df['nursery'].apply(convert_binary)
student_df['higher'] = student_df['higher'].apply(convert_binary)
student_df['internet'] = student_df['internet'].apply(convert_binary)
student_df['romantic'] = student_df['romantic'].apply(convert_binary)

# %%
# sanity check 
student_df['schoolsup'].value_counts()
# Out:
# 0    344
# 1     51
# Name: schoolsup, dtype: int64

# %% [markdown]
# **Extracting teacher from 'Mjob' and 'Fjob'**<br>
# Hypothesis: If the student's Mother or Father works as a teacher, the grade will be higher.

# %%
# extracting teacher from the Mjob and Fjob
def extract_teacher(text):
    if "teacher" in text['Mjob'] or "teacher" in text['Fjob'] :
        return 1
    return 0

student_df['parent_is_teacher'] = student_df[['Mjob', 'Fjob']].apply(lambda x: extract_teacher(x),axis=1)
student_df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   freetime goout  Dalc  Walc  health  absences  G1  G2  G3  parent_is_teacher
# 0        3     4     1     1       3         6   5   6   6                  1
# 1        3     3     1     1       3         4   5   5   6                  0
# 2        3     2     2     3       3        10   7   8  10                  0
# 3        2     2     1     1       5         2  15  14  15                  0
# 4        3     2     1     2       5         4   6  10  10                  0
#
# [5 rows x 34 columns]

# %%
print("Number of student whose parent works as teacher:", len(student_df[student_df['parent_is_teacher']==1]))
# Out:
# Number of student whose parent works as teacher: 75

# %%
student_df['average_grade'] = (student_df["G1"] + student_df['G2'] + student_df['G3']) / 3

sns.boxplot(data=student_df, x='parent_is_teacher', y='average_grade')

parent_is_teacher = student_df.query("parent_is_teacher == 1 ")
parent_not_teacher = student_df.query("parent_is_teacher == 0 ")

print(f"""
Mean :
Parent is teacher: {parent_is_teacher.average_grade.mean():.2f}
Parent not teacher: {parent_not_teacher.average_grade.mean():.2f}
""")
# Out:
# Mean :
# Parent is teacher: 11.33
# Parent not teacher: 10.53

# %% [markdown]
# **Conclusion**<br>
# Student whose one of their parent works as a teacher scores slightly higher in test and quizzes.

# %% [markdown]
# **Alcohol Consumption In a Week vs Final Grade**<br>
# Creating column of overall alcohol consumption in a week for each entry. The relationship between these two features are depicted using a simple regression plot.

# %%
student_df['alc_consumption'] = (5*student_df['Dalc'] + 2*student_df['Walc'])/7

# %%
sns.regplot(x='alc_consumption', y='G3', data=student_df).set(xlabel='Alcohol Consumption In A Week', title='Alcohol Consumption vs Final Grade')
# Out:
# [Text(0.5, 0, 'Alcohol Consumption In A Week'),
#  Text(0.5, 1.0, 'Alcohol Consumption vs Final Grade')]

# %% [markdown]
# **Observations**<br>
# Higher overall alcohol consumption in a week corresponds to a lower final grade.

# %% [markdown]
# **G1 & G2 vs Final Grade (G3)**

# %%
sns.regplot(x="G1", y="G3", data=student_df).set(title='First period grade vs Final grade')
# Out:
# [Text(0.5, 1.0, 'First period grade vs Final grade')]

# %%
sns.regplot(x="G2", y="G3", data=student_df).set(title='Second period grade vs Final grade')
# Out:
# [Text(0.5, 1.0, 'Second period grade vs Final grade')]

# %% [markdown]
# **Observations**<br>
# The higher the student's score in the first, second period, the higher the student scores in final grade.

# %% [markdown]
# **Study Time & Going Out with Friends vs Final Grade**

# %%
sns.regplot(x='studytime', y='G3', data=student_df)
# Out:
# <AxesSubplot:xlabel='studytime', ylabel='G3'>

# %%
sns.regplot(x='goout', y='G3', data=student_df).set(xlabel='Going out with friends', title="Going out vs G3")
# Out:
# [Text(0.5, 0, 'Going out with friends'), Text(0.5, 1.0, 'Going out vs G3')]

# %% [markdown]
# **Observations**<br>
# Students who study more get better grades. In constrast, students who going out with friends more or study less get lower grades.

# %% [markdown]
# **Failures vs Final Grade**

# %%
sns.regplot(x='failures', y='G3', data=student_df).set(title='failures vs G3')
# Out:
# [Text(0.5, 1.0, 'failures vs G3')]

# %% [markdown]
# **Observations**<br>
# Students who have less past class failures get better grades.

# %% [markdown]
# **Drop unwanted columns**<br>
# Dropping columns that will not be used for modelling.

# %%
student_df = student_df.drop([
    'reason',
    'Mjob', 
    'Fjob',
    'average_grade',
    'Dalc',
    'Walc'
], axis=1)

# %%
# sanity check
student_df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu guardian  traveltime  \
# 0       GP   F   18       U     GT3       A     4     4   mother           2
# 1       GP   F   17       U     GT3       T     1     1   father           1
# 2       GP   F   15       U     LE3       T     1     1   mother           1
# 3       GP   F   15       U     GT3       T     4     2   mother           1
# 4       GP   F   16       U     GT3       T     3     3   father           1
# ..     ...  ..  ...     ...     ...     ...   ...   ...      ...         ...
# 390     MS   M   20       U     LE3       A     2     2    other           1
# 391     MS   M   17       U     LE3       T     3     1   mother           2
# 392     MS   M   21       R     GT3       T     1     1    other           1
# 393     MS   M   18       R     LE3       T     3     2   mother           3
# 394     MS   M   19       U     LE3       T     1     1   father           1
#
# ...

# %% [markdown]
# **Checking for Outliers**

# %%
plt.figure(figsize=(25,7))
student_df.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **absences** <br>
# Remove rows that have number of school absences exceeds 30, in order to avoid disrupting the accuracy of prediction.

# %%
fig, axs = plt.subplots(1,2)
axs[0].boxplot(data=student_df, x='absences')
axs[0].set_title('all data of absences')

axs[1].boxplot(data=student_df, x='absences')
axs[1].set_ylim(-1,30)
axs[1].set_title('cropped at 30')

plt.tight_layout()
plt.show()

# %%
student_df = student_df[(student_df['absences'] <= 30)]

# %% [markdown]
# Final Data after Outlier Removal

# %%
plt.figure(figsize=(25,5))
student_df.boxplot()
# Out:
# <AxesSubplot:>

# %%
student_df.shape
# Out:
# (390, 30)

# %%
student_df.to_csv('data_clean.csv', index=False)

# %% [markdown]
# Creating dummy data for Categorical Variables

# %%
# all data that are categorical
df_cat = student_df.select_dtypes(include='object')
df_dummies = pd.get_dummies(student_df, columns=df_cat.columns)

# %%
# sanity check
df_dummies
# Out:
#      age  Medu  Fedu  traveltime  studytime  failures  schoolsup  famsup  \
# 0     18     4     4           2          2         0          1       0
# 1     17     1     1           1          2         0          0       1
# 2     15     1     1           1          2         3          1       0
# 3     15     4     2           1          3         0          0       1
# 4     16     3     3           1          2         0          0       1
# ..   ...   ...   ...         ...        ...       ...        ...     ...
# 390   20     2     2           1          2         2          0       1
# 391   17     3     1           2          1         0          0       0
# 392   21     1     1           1          1         3          0       0
# 393   18     3     2           3          1         0          0       0
# 394   19     1     1           1          1         0          0       0
#
#      paid  activities  ...  sex_M  address_R  address_U  famsize_GT3  \
# ...

# %% [markdown]
# **Visualizing Data Correlation**

# %%
plt.figure(figsize=(18,18))
sns.heatmap(student_df.corr(), vmin=-1, cmap="coolwarm", annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Top 10 highest numerical attributes correlates with G3 value

# %%
corr_matrix = student_df.corr()
corr_matrix["G3"].sort_values(ascending=False).head(10)
# Out:
# G3                   1.000000
# G2                   0.904797
# G1                   0.801391
# Medu                 0.220050
# higher               0.184156
# Fedu                 0.154878
# paid                 0.102166
# internet             0.099973
# studytime            0.096151
# parent_is_teacher    0.072934
# Name: G3, dtype: float64

# %% [markdown]
# **Input-Output**

# %%
X = df_dummies.drop('G3', axis=1)
y = df_dummies['G3']

# %%
X
# Out:
#      age  Medu  Fedu  traveltime  studytime  failures  schoolsup  famsup  \
# 0     18     4     4           2          2         0          1       0
# 1     17     1     1           1          2         0          0       1
# 2     15     1     1           1          2         3          1       0
# 3     15     4     2           1          3         0          0       1
# 4     16     3     3           1          2         0          0       1
# ..   ...   ...   ...         ...        ...       ...        ...     ...
# 390   20     2     2           1          2         2          0       1
# 391   17     3     1           2          1         0          0       0
# 392   21     1     1           1          1         3          0       0
# 393   18     3     2           3          1         0          0       0
# 394   19     1     1           1          1         0          0       0
#
#      paid  activities  ...  sex_M  address_R  address_U  famsize_GT3  \
# ...

# %%
y
# Out:
# 0       6
# 1       6
# 2      10
# 3      15
# 4      10
#        ..
# 390     9
# 391    16
# 392     7
# 393    10
# 394     9
# Name: G3, Length: 390, dtype: int64

# %% [markdown]
# **Feature Selection**<br>
# Finding important features using ExtraTreesRegressor.

# %%
from sklearn.ensemble import ExtraTreesRegressor
selection = ExtraTreesRegressor(random_state = 42)
selection.fit(X, y)
# Out:
# ExtraTreesRegressor(random_state=42)

# %%
plt.figure(figsize = (12,8))
feat_importances = pd.Series(selection.feature_importances_, index=X.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()

# %% [markdown]
# Based on the graph above, the top 8 importance features are *activities, famrel, health, goout, age, failures, studytime, absences, G1, G2*. These features will be selected to train the regression model for predicting the final grade(G3) of a student.

# %%
X_new = df_dummies[['activities', 
                    'famrel', 
                    'health', 
                    'goout', 
                    'failures', 
                    'age', 
                    'studytime', 
                    'absences', 
                    'G1', 
                    'G2']]
y_new = df_dummies['G3']

# %%
X_new
# Out:
#      activities  famrel  health  goout  failures  age  studytime  absences  \
# 0             0       4       3      4         0   18          2         6
# 1             0       5       3      3         0   17          2         4
# 2             0       4       3      2         3   15          2        10
# 3             1       3       5      2         0   15          3         2
# 4             0       4       5      2         0   16          2         4
# ..          ...     ...     ...    ...       ...  ...        ...       ...
# 390           0       5       4      4         2   20          2        11
# 391           0       2       2      5         0   17          1         3
# 392           0       5       3      3         3   21          1         3
# 393           0       4       5      1         0   18          1         0
# 394           0       3       5      3         0   19          1         5
#
#      G1  G2
# 0     5   6
# 1     5   5
# 2     7   8
# 3    15  14
# ...

# %%
y_new
# Out:
# 0       6
# 1       6
# 2      10
# 3      15
# 4      10
#        ..
# 390     9
# 391    16
# 392     7
# 393    10
# 394     9
# Name: G3, Length: 390, dtype: int64

# %% [markdown]
# **Train-Test Split Data**

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_new, y_new,
                                    test_size = 0.2,
                                    random_state = 42)

# %%
#sanity check
len(X_test)/len(X_new)
# Out:
# 0.2

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((312, 10), (312,), (78, 10), (78,))

# %% [markdown]
# Reset index of training and testing data

# %%
X_train.reset_index(drop=True, inplace=True)
X_test.reset_index(drop=True, inplace=True)

# %%
# sanity check
X_train
# Out:
#      activities  famrel  health  goout  failures  age  studytime  absences  \
# 0             1       5       4      2         0   18          3         8
# 1             1       3       4      4         0   16          3         2
# 2             0       3       4      3         0   17          2         2
# 3             0       3       3      2         0   18          1         4
# 4             1       4       5      4         1   17          3         0
# ..          ...     ...     ...    ...       ...  ...        ...       ...
# 307           0       3       3      3         0   15          4         0
# 308           1       5       5      3         0   16          3         2
# 309           0       4       3      3         0   18          2         2
# 310           0       4       5      4         1   19          1         4
# 311           0       4       2      5         0   15          2        26
#
#      G1  G2
# 0    14  13
# 1    10   9
# 2    10  11
# 3    10  10
# ...

# %% [markdown]
# Export training data

# %%
X_train.to_csv('X_train.csv',index=False)

# %% [markdown]
# **Standardization**<br>
# Data standardization is the process of rescaling the attributes so that they have mean as 0 and variance as 1.

# %%
# importing libraries
from sklearn.preprocessing import StandardScaler

cols = X_train.columns.to_list()

standardizer = StandardScaler()

X_train[cols] = standardizer.fit_transform(X_train[cols])
X_test[cols] = standardizer.transform(X_test[cols])

# %%
X_train
# Out:
#      activities    famrel    health     goout  failures       age  studytime  \
# 0      1.012904  1.210638  0.333414 -1.042350 -0.424040  1.042975   1.095878
# 1      1.012904 -1.024386  0.333414  0.816011 -0.424040 -0.560021   1.095878
# 2     -0.987261 -1.024386  0.333414 -0.113169 -0.424040  0.241477  -0.083136
# 3     -0.987261 -1.024386 -0.399158 -1.042350 -0.424040  1.042975  -1.262149
# 4      1.012904  0.093126  1.065986  0.816011  1.014008  0.241477   1.095878
# ..          ...       ...       ...       ...       ...       ...        ...
# 307   -0.987261 -1.024386 -0.399158 -0.113169 -0.424040 -1.361519   2.274891
# 308    1.012904  1.210638  1.065986 -0.113169 -0.424040 -0.560021   1.095878
# 309   -0.987261  0.093126 -0.399158 -0.113169 -0.424040  1.042975  -0.083136
# 310   -0.987261  0.093126  1.065986  0.816011  1.014008  1.844473  -1.262149
# 311   -0.987261  0.093126 -1.131730  1.745192 -0.424040 -1.361519  -0.083136
#
#      absences        G1        G2
# ...

# %% [markdown]
# **Training Machine Learning**<br>
# R-squared score, mean absolute error (MAE) and mean squared error (MSE) will be used as a performance metrics, as this is a regression model.

# %%
# importing libraries
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %% [markdown]
# **Linear Regression**

# %%
linear = LinearRegression()
linear.fit(X_train,y_train)
y_pred = linear.predict(X_test)

# calculate R-squared
r2_linear = r2_score(y_test, y_pred)

# calculate mean absolute error
mae_linear = mean_absolute_error(y_test, y_pred)

# calculate mean squared error
mse_linear = mean_squared_error(y_test, y_pred)

print(f"R2-score: {r2_linear:.4f}")
print(f"MAE score: {mae_linear:.4f}")
print(f"MSE score: {mse_linear:.4f}")
# Out:
# R2-score: 0.8237
# MAE score: 1.2683
# MSE score: 3.5978

# %% [markdown]
# Impact of features on the modelling

# %%
# calculate the feature coeffients
coefficients = linear.coef_

# Create a DataFrame to store the feature names and their corresponding coefficients
df_coefficients = pd.DataFrame({'Feature': cols, 'Coefficient': coefficients})
df_coefficients
# Out:
#       Feature  Coefficient
# 0  activities    -0.200609
# 1      famrel     0.395452
# 2      health     0.073808
# 3       goout     0.069061
# 4    failures    -0.200751
# 5         age    -0.244771
# 6   studytime    -0.159043
# 7    absences     0.499349
# 8          G1     0.581589
# 9          G2     3.645956

# %% [markdown]
# *Analyze the coefficients*<br>
# Positive coefficients indicate a positive relationship with the target variable, while negative coefficients indicate a negative relationship.

# %% [markdown]
# Visualizing the output of linear regression model

# %%
sns.regplot(x=y_test, y=y_pred).set(title='Linear Regression')
# Out:
# [Text(0.5, 1.0, 'Linear Regression')]

# %% [markdown]
# **k-nearest neighbors (KNN)**

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn = KNeighborsRegressor()
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)

# Calculate R-squared
r2_knn = r2_score(y_test, y_pred)

# Calculate mean absolute error
mae_knn = mean_absolute_error(y_test, y_pred)

# calculate mean squared error
mse_knn = mean_squared_error(y_test, y_pred)

print(f"R2-score: {r2_knn:.4f}")
print(f"MAE score: {mae_knn:.4f}")
print(f"MSE score: {mse_knn:.4f}")
# Out:
# R2-score: 0.5828
# MAE score: 2.0590
# MSE score: 8.5144

# %% [markdown]
# *Hyper-parameter tuning*

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_neighbors': [3, 5, 7],
    'weights': ['uniform', 'distance'],
    'p': [1, 2]
}

grid_search = GridSearchCV(estimator=knn, param_grid=param_grid, scoring='neg_mean_squared_error', cv=5)
grid_search.fit(X_train, y_train)

best_params = grid_search.best_params_
knn_best = grid_search.best_estimator_

y_pred = knn_best.predict(X_test)

# Calculate R-squared
r2_knn_best = r2_score(y_test, y_pred)

# Calculate mean absolute error
mae_knn_best = mean_absolute_error(y_test, y_pred)

# calculate mean squared error
mse_knn_best = mean_squared_error(y_test, y_pred)

print(f"R2-score: {r2_knn_best:.4f}")
print(f"MAE score: {mae_knn_best:.4f}")
print(f"MSE score: {mse_knn_best:.4f}")
# Out:
# R2-score: 0.6897
# MAE score: 1.8205
# MSE score: 6.3316

# %%
sns.regplot(x=y_test, y=y_pred).set(title='KNN')
# Out:
# [Text(0.5, 1.0, 'KNN')]

# %% [markdown]
# **Decision Tree**

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
decision_tree = DecisionTreeRegressor(random_state=0)
decision_tree.fit(X_train, y_train)

y_pred = decision_tree.predict(X_test)

# Calculate R-squared
r2_dt = r2_score(y_test, y_pred)

# Calculate mean absolute error
mae_dt = mean_absolute_error(y_test, y_pred)

# calculate mean squared error
mse_dt = mean_squared_error(y_test, y_pred)

print(f"R2-score: {r2_dt:.4f}")
print(f"MAE score: {mae_dt:.4f}")
print(f"MSE score: {mse_dt:.4f}")
# Out:
# R2-score: 0.7041
# MAE score: 1.2692
# MSE score: 6.0385

# %% [markdown]
# *Hyper-parameter tuning*

# %%
param_grid = {
    'max_depth': [None, 5, 10, 15],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2']
}

grid_search = GridSearchCV(estimator=decision_tree, param_grid=param_grid, scoring='neg_mean_squared_error', cv=5)
grid_search.fit(X_train, y_train)

best_params = grid_search.best_params_
dt_best = grid_search.best_estimator_

y_pred = dt_best.predict(X_test)

# Calculate R-squared
r2_dt_best = r2_score(y_test, y_pred)

# Calculate mean absolute error
mae_dt_best = mean_absolute_error(y_test, y_pred)

# calculate mean squared error
mse_dt_best = mean_squared_error(y_test, y_pred)

print(f"R2-score: {r2_dt_best:.4f}")
print(f"MAE score: {mae_dt_best:.4f}")
print(f"MSE score: {mse_dt_best:.4f}")
# Out:
# R2-score: 0.7972
# MAE score: 1.2636
# MSE score: 4.1396

# %%
sns.regplot(x=y_test, y=y_pred).set(title='Decision Tree')
# Out:
# [Text(0.5, 1.0, 'Decision Tree')]

# %% [markdown]
# **Stochastic Gradient Descent (SGD)**

# %%
from sklearn.linear_model import SGDRegressor

# %%
sgd = SGDRegressor(random_state=0)
sgd.fit(X_train, y_train)

y_pred = sgd.predict(X_test)

# Calculate R-squared
r2_sgd = r2_score(y_test, y_pred)

# Calculate mean absolute error
mae_sgd = mean_absolute_error(y_test, y_pred)

# calculate mean squared error
mse_sgd = mean_squared_error(y_test, y_pred)

print(f"R2-score: {r2_sgd:.4f}")
print(f"MAE score: {mae_sgd:.4f}")
print(f"MSE score: {mse_sgd:.4f}")
# Out:
# R2-score: 0.8221
# MAE score: 1.2771
# MSE score: 3.6305

# %% [markdown]
# *Hyper-parameter tuning*

# %%
param_grid = {
    'penalty': ['l1', 'l2', 'elasticnet'],
    'alpha': [0.0001, 0.001, 0.01],
    'learning_rate': ['constant', 'optimal', 'invscaling', 'adaptive'],
    'max_iter': [1000, 2000, 5000]
}

sgd = SGDRegressor(random_state=0)

grid_search = GridSearchCV(estimator=sgd, param_grid=param_grid, scoring='neg_mean_squared_error', cv=5)
grid_search.fit(X_train, y_train)

best_params = grid_search.best_params_
sgd_best = grid_search.best_estimator_

y_pred = sgd_best.predict(X_test)

# Calculate R-squared
r2_sgd_best = r2_score(y_test, y_pred)

# Calculate mean absolute error
mae_sgd_best = mean_absolute_error(y_test, y_pred)

# calculate mean squared error
mse_sgd_best = mean_squared_error(y_test, y_pred)

print(f"R2-score: {r2_sgd_best:.4f}")
print(f"MAE score: {mae_sgd_best:.4f}")
print(f"MSE score: {mse_sgd_best:.4f}")
# Out:
# R2-score: 0.8229
# MAE score: 1.2679
# MSE score: 3.6151

# %%
sns.regplot(x=y_test, y=y_pred).set(title='SGD')
# Out:
# [Text(0.5, 1.0, 'SGD')]

# %% [markdown]
# **Result of Models**

# %%
mae_scores = [mae_linear, mae_knn, mae_knn_best, mae_dt, mae_dt_best, mae_sgd, mae_sgd_best]
r2_scores = [r2_linear, r2_knn, r2_knn_best, r2_dt, r2_dt_best, r2_sgd, r2_sgd_best]
mse_scores = [mse_linear, mse_knn, mse_knn_best, mse_dt, mse_dt_best, mse_sgd, mse_sgd_best]
methods = ["Linear Regression", "KNN", "KNN with Grid Search", "Decision Tree",  "Decision Tree with Grid Search", "SGD", "SGD with Grid Search"]

df_results = pd.DataFrame({
    "R2-Score": r2_scores,
    "MAE": mae_scores,
    "MSE": mse_scores,
},index = methods)

df_results.sort_values(by='R2-Score', ascending=False)
# Out:
#                                 R2-Score       MAE       MSE
# Linear Regression               0.823703  1.268309  3.597803
# SGD with Grid Search            0.822857  1.267940  3.615067
# SGD                             0.822103  1.277112  3.630457
# Decision Tree with Grid Search  0.797156  1.263563  4.139560
# Decision Tree                   0.704108  1.269231  6.038462
# KNN with Grid Search            0.689741  1.820486  6.331646
# KNN                             0.582785  2.058974  8.514359

# %% [markdown]
# From the table above, it can be seen that the Linear Regression model performs the best, which reaches 0.8237 of R2-score, 1.2683 of MAE and 3.5978 of MSE. SGD performs similarly as Linear Regression, followed by Decision Tree at the third place and KNN performs the worst.

# %% [markdown]
# **Export model for real-time prediction**<br>
# Linear Regression model is selected to predict student performance(G3).

# %%
from joblib import dump
dump(linear, 'linear_reg_model.joblib')
# Out:
# ['linear_reg_model.joblib']
